# %% [markdown]
# <a href="https://colab.research.google.com/github/Geetanjally/NLP/blob/main/1_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NLP**

# %% [markdown]
# ![NLP.png](data:image/png;base64,...)

# %%
# NLP = making computers understand human language by breaking it into tokens, converting it into numbers, and applying ML/DL models for tasks
# like classification, translation, or summarization.
